# %% [markdown]
# This YOLOv7 🚀 notebook by Vitis AI presents simple train, validate and predict examples to help start your AI adventure.
# We hope that the resources in this notebook will help you get the most out of YOLOv7.

# %% [markdown]
# # Setup and Prepare

# %% [markdown]
# Clone GitHub repository, install dependencies and check PyTorch and GPU.

# %%
# !pip install -r yolov7/requirements.txt
# Out:
# Looking in indexes: https://xcdpython.xilinx.com/simple
# Requirement already satisfied: matplotlib>=3.2.2 in /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages (from -r yolov7/requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: numpy<1.24.0,>=1.18.5 in /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages (from -r yolov7/requirements.txt (line 5)) (1.21.6)
# ...

# %% [markdown]
# ## Prepare the dataset

# %% [markdown]
# ##### Download COCO2017 dataset.(refer to this repo https://github.com/WongKinYiu/yolov7)

# %%
# %cd yolov7/
# !bash scripts/get_coco.sh
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels-segments.zip  ...
# Downloading http://images.cocodataset.org/zips/train2017.zip ...
# Downloading http://images.cocodataset.org/zips/val2017.zip ...
# Downloading http://images.cocodataset.org/zips/test2017.zip ...

# %% [markdown]
# ### After download the coco dataset, the directory structure should be:
# ```markdown
# + yolov7/
#     + coco/
#         + labels/
#         + annotations/
#         + images/
#         + test-dev2017.txt
#         + train2017.txt
#         + val2017.txt
# ```

# %% [markdown]
# # Detect

# %% [markdown]
# detect.py runs YOLOv7 inference on a variety of sources, downloading models automatically from the latest YOLOv7 release, and saving results to runs/detect. Example inference sources are:

# %%
# %cd yolov7/
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source /group/dphi_algo_scratch_13/fangyuan/datasets/coco/images/test2017/000000100004.jpg
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/group/dphi_algo_scratch_13/fangyuan/datasets/coco/images/test2017/000000100004.jpg', update=False, view_img=False, weights=['yolov7.pt'])
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#                                CUDA:1 (Tesla P100-PCIE-16GB, 16280.875MB)
#                                CUDA:2 (Tesla P100-PCIE-16GB, 16280.875MB)
#                                CUDA:3 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
# Model Summary: 392 layers, 36926621 parameters, 36926621 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 9 cars, 3 trucks, Done. (20.0ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs/detect/exp/000000100004.jpg
# Done. (0.099s)
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ![avatar](./example.jpg)

# %% [markdown]
# # Eval

# %% [markdown]
# ## Eval float model

# %%
# for float training
# %cd yolov7/
# !python test_nndct.py --data data/coco.yaml --img 640 --batch 1 --conf 0.001 --iou 0.65 --device 0 --weights yolov7.pt --name yolov7_640_val --quant_mode float
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='data/coco.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolov7_640_val', nndct_qat=False, no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', v5_metric=False, verbose=False, weights=['yolov7.pt'])
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
# Model Summary: 392 layers, 36926621 parameters, 36926621 gradients
#  Convert model to Traced-model...
#  model is traced!
#
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# val: Scanning 'coco/val2017.cache' images and labels... 4952 found, 48 missing,
#                Class      Images      Labels           P           R      mAP@.5
#                  all        5000       36335       0.718       0.638       0.689       0.495
# Speed: 20.9/0.9/21.8 ms inference/NMS/total per 640x640 image at batch-size 1
#
# Evaluating pycocotools mAP... saving runs/test/yolov7_640_val/yolov7_predictions.json...
# loading annotations into memory...
# Done (t=0.41s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.09s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=55.97s).
# Accumulating evaluation results...
# DONE (t=11.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.695
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.383
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.637
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.688
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.541
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.836
# Results saved to runs/test/yolov7_640_val
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ## Eval  Post-training quanzization model

# %% [markdown]
# ### Run calibration

# %%
# %cd yolov7/
# !python test_nndct.py --data data/coco.yaml --img 640 --batch 1 --conf 0.001 --iou 0.65 --device 0 --weights yolov7.pt --name yolov7_640_val --quant_mode calib --nndct_convert_sigmoid_to_hsigmoid --nndct_convert_silu_to_hswish
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='data/coco.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolov7_640_val', nndct_qat=False, no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', v5_metric=False, verbose=False, weights=['yolov7.pt'])
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
# Model Summary: 392 layers, 36926621 parameters, 36926621 gradients
#  Convert model to Traced-model...
#
# [VAIQ_NOTE]: OS and CPU information:
#                system --- Linux
#                  node --- xcdl190200
#               release --- 4.4.0-134-generic
#               version --- #160-Ubuntu SMP Wed Aug 15 14:58:00 UTC 2018
#               machine --- x86_64
#             processor --- x86_64
#
# [VAIQ_NOTE]: Tools version information:
#                   GCC --- GCC 9.4.0
#                python --- 3.7.12
#               pytorch --- 1.12.1
#         vai_q_pytorch --- 3.0.0+1bbeff9+torch1.12.1
#
# [VAIQ_NOTE]: GPU information:
#           device name --- Tesla P100-PCIE-16GB
#      device available --- True
#          device count --- 1
#        current device --- 0
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2622.1
#
# [VAIQ_NOTE]: =>Doing weights equalization...
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(nndct/Model.py)
#
# [VAIQ_NOTE]: =>Get module with quantization.
#  model is traced!
#
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# val: Scanning 'coco/val2017.cache' images and labels... 4952 found, 48 missing,
#                Class      Images      Labels           P           R      mAP@.5
#
# [VAIQ_NOTE]: =>Exporting quant config.(nndct/quant_info.json)
#                  all        1000        7117       0.684       0.638       0.677        0.43
# Speed: 370.3/1.0/371.3 ms inference/NMS/total per 640x640 image at batch-size 1
#
# Evaluating pycocotools mAP... saving runs/test/yolov7_640_val2/yolov7_predictions.json...
# loading annotations into memory...
# Done (t=0.42s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=1.39s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=18.09s).
# Accumulating evaluation results...
# DONE (t=4.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.133
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.097
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.123
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.081
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.127
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.157
# Results saved to runs/test/yolov7_640_val2
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ### run eval

# %%
# %cd yolov7/
# !python test_nndct.py --data data/coco.yaml --img 640 --batch 1 --conf 0.001 --iou 0.65 --device 0 --weights yolov7.pt --name yolov7_640_val --quant_mode test --nndct_convert_sigmoid_to_hsigmoid --nndct_convert_silu_to_hswish
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='data/coco.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolov7_640_val', nndct_qat=False, no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', v5_metric=False, verbose=False, weights=['yolov7.pt'])
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
# Model Summary: 392 layers, 36926621 parameters, 36926621 gradients
#  Convert model to Traced-model...
#
# [VAIQ_NOTE]: OS and CPU information:
#                system --- Linux
#                  node --- xcdl190200
#               release --- 4.4.0-134-generic
#               version --- #160-Ubuntu SMP Wed Aug 15 14:58:00 UTC 2018
#               machine --- x86_64
#             processor --- x86_64
#
# [VAIQ_NOTE]: Tools version information:
#                   GCC --- GCC 9.4.0
#                python --- 3.7.12
#               pytorch --- 1.12.1
#         vai_q_pytorch --- 3.0.0+1bbeff9+torch1.12.1
#
# [VAIQ_NOTE]: GPU information:
#           device name --- Tesla P100-PCIE-16GB
#      device available --- True
#          device count --- 1
#        current device --- 0
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization test process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2236.4
#
# [VAIQ_NOTE]: =>Doing weights equalization...
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(nndct/Model.py)
#
# [VAIQ_NOTE]: =>Get module with quantization.
#  model is traced!
#
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# val: Scanning 'coco/val2017.cache' images and labels... 4952 found, 48 missing,
#                Class      Images      Labels           P           R      mAP@.5
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input Model::input_0
#   key
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/prim_ops.py:116: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if not (list(self.node.out_tensors[0].shape[1:]) == list(input.size())[1:]):
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/torchquantizer.py:55: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if inf.sum() > 0 or nan.sum() > 0:
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/fix_ops.py:69: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   tensor.storage().size() != tensor.numel()):
#
# [VAIQ_NOTE]: Model_int.onnx is generated.(nndct/Model_int.onnx)
#
# [VAIQ_NOTE]: Model_int.pt is generated.(nndct/Model_int.pt)
#
# [VAIQ_NOTE]: =>Converting to xmodel ...
#
# [VAIQ_NOTE]: =>Dumping 'Model_0'' checking data...
#
# [VAIQ_NOTE]: =>Finsh dumping data.(nndct/deploy_check_data_int/Model_0)
#
# [VAIQ_NOTE]: =>Successfully convert 'Model_0' to xmodel.(nndct/Model_0_int.xmodel)
#                  all        5000       36335        0.68       0.594       0.637       0.392
# Speed: 98.7/1.0/99.6 ms inference/NMS/total per 640x640 image at batch-size 1
#
# Evaluating pycocotools mAP... saving runs/test/yolov7_640_val3/yolov7_predictions.json...
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=6.38s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=65.60s).
# Accumulating evaluation results...
# DONE (t=14.80s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.408
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.644
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.459
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.445
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.543
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.327
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.551
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.607
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.468
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.754
# Results saved to runs/test/yolov7_640_val3
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ### dump model

# %%
# %cd yolov7/
# !python test_nndct.py --data data/coco.yaml --img 640 --batch 1 --conf 0.001 --iou 0.65 --device 0 --weights yolov7.pt --name yolov7_640_val --quant_mode test --nndct_convert_sigmoid_to_hsigmoid --nndct_convert_silu_to_hswish --dump_model
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='data/coco.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolov7_640_val', nndct_qat=False, no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', v5_metric=False, verbose=False, weights=['yolov7.pt'])
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
# Model Summary: 392 layers, 36926621 parameters, 36926621 gradients
#  Convert model to Traced-model...
#
# [VAIQ_NOTE]: OS and CPU information:
#                system --- Linux
#                  node --- xcdl190200
#               release --- 4.4.0-134-generic
#               version --- #160-Ubuntu SMP Wed Aug 15 14:58:00 UTC 2018
#               machine --- x86_64
#             processor --- x86_64
#
# [VAIQ_NOTE]: Tools version information:
#                   GCC --- GCC 9.4.0
#                python --- 3.7.12
#               pytorch --- 1.12.1
#         vai_q_pytorch --- 3.0.0+1bbeff9+torch1.12.1
#
# [VAIQ_NOTE]: GPU information:
#           device name --- Tesla P100-PCIE-16GB
#      device available --- True
#          device count --- 1
#        current device --- 0
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization test process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2534.6
#
# [VAIQ_NOTE]: =>Doing weights equalization...
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(nndct/Model.py)
#
# [VAIQ_NOTE]: =>Get module with quantization.
#  model is traced!
#
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# val: Scanning 'coco/val2017.cache' images and labels... 4952 found, 48 missing,
#                Class      Images      Labels           P           R      mAP@.5
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input Model::input_0
#   key
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/prim_ops.py:116: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if not (list(self.node.out_tensors[0].shape[1:]) == list(input.size())[1:]):
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/torchquantizer.py:55: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if inf.sum() > 0 or nan.sum() > 0:
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/fix_ops.py:69: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   tensor.storage().size() != tensor.numel()):
#
# [VAIQ_NOTE]: Model_int.onnx is generated.(nndct/Model_int.onnx)
#
# [VAIQ_NOTE]: Model_int.pt is generated.(nndct/Model_int.pt)
#
# [VAIQ_NOTE]: =>Converting to xmodel ...
#
# [VAIQ_NOTE]: =>Dumping 'Model_0'' checking data...
#
# [VAIQ_NOTE]: =>Finsh dumping data.(nndct/deploy_check_data_int/Model_0)
#
# [VAIQ_NOTE]: =>Successfully convert 'Model_0' to xmodel.(nndct/Model_0_int.xmodel)
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ## Quantization aware training

# %%
# %cd yolov7/
# !python -m torch.distributed.launch --nproc_per_node 4 --master_port 9004 train_qat.py --workers 8 --device 0,1,2,3 --batch-size 32 --data data/coco.yaml --img 640 640 --cfg cfg/training/yolov7.yaml --weights yolov7.pt --name yolov7_qat --hyp data/hyp.scratch.p5_qat.yaml --nndct_convert_sigmoid_to_hsigmoid --nndct_convert_silu_to_hswish --log_threshold_scale 100
# %cd ../
# Out:
# [Errno 2] No such file or directory: 'yolov7/'
# /workspace/internal-models/pytorch/yolov7/yolov7
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#                                CUDA:1 (Tesla P100-PCIE-16GB, 16280.875MB)
#                                CUDA:2 (Tesla P100-PCIE-16GB, 16280.875MB)
#                                CUDA:3 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 4 nodes.
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/coco.yaml', device='0,1,2,3', entity=None, epochs=300, evolve=False, exist_ok=False, freeze=[0], global_rank=0, hyp='data/hyp.scratch.p5_qat.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=0, log_threshold_scale=100.0, multi_scale=False, name='yolov7_qat', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7_qat2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=8, world_size=4)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.0001, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.0, paste_in=0.15, loss_ota=1
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1    460282  models.yolo.IDetect                     [80, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# RepConv.fuse_repvgg_block
# Model Summary: 432 layers, 37622682 parameters, 37622682 gradients, 106.5 GFLOPS
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# RepConv.fuse_repvgg_block
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# IDetect.fuse
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# IDetect.fuse
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 417 layers, 36929178 parameters, 36929178 gradients, 105.2 GFLOPS
# Transferred 522/536 items from yolov7.pt
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 1175.4
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_NOTE]: =>Exporting quant config.(.vai_qat/quant_info.json)
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2841.8
# Scaled weight_decay = 0.0005
# Optimizer groups: 92 .bias, 92 conv.weight, 92 other
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
# train: Scanning 'coco/train2017.cache' images and labels... 117266 found, 1021 m
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
#
# [VAIQ_NOTE]: Processing ops...
#                                                   | 407/? [00:00<00:00, 1620.96i
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 1253.4
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 1260.2
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 953.29
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_NOTE]: =>Exporting quant config.(.vai_qat/quant_info.json)
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: =>Exporting quant config.(.vai_qat/quant_info.json)
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: =>Exporting quant config.(.vai_qat/quant_info.json)
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2835.6
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2859.4
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2770.5
# val: Scanning 'coco/val2017.cache' images and labels... 4952 found, 48 missing,
# train: Scanning 'coco/train2017.cache' images and labels... 117266 found, 1021 m
#
# train: Scanning 'coco/train2017.cache' images and labels... 117266 found, 1021 m
# train: Scanning 'coco/train2017.cache' images and labels... 117266 found, 1021 m
# anchors/target = 4.42, Best Possible Recall (BPR) = 0.9912
# Image sizes 640 train, 640 test
# Using 8 dataloader workers
# Logging results to runs/train/yolov7_qat2
# Starting training for 300 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#   0%|                                                  | 0/3697 [00:00<?, ?it/s]^C
#   0%|                                                  | 0/3697 [00:20<?, ?it/s]
# Traceback (most recent call last):
#   File "train_qat.py", line 675, in <module>
# Traceback (most recent call last):
#   File "train_qat.py", line 675, in <module>
#     train(hyp, opt, device, tb_writer)
#   File "train_qat.py", line 399, in train
#     train(hyp, opt, device, tb_writer)
#   File "train_qat.py", line 399, in train
#     pred = model(imgs)  # forward
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 1008, in forward
#     pred = model(imgs)  # forward
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     output = self._run_ddp_forward(*inputs, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 969, in _run_ddp_forward
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 1008, in forward
#     return module_to_run(*inputs[0], **kwargs[0])
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     output = self._run_ddp_forward(*inputs, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 969, in _run_ddp_forward
#     return forward_call(*input, **kwargs)
#     return module_to_run(*inputs[0], **kwargs[0])
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/utils/torch_utils.py", line 605, in forward
#     return forward_call(*input, **kwargs)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/utils/torch_utils.py", line 605, in forward
# WARNING:torch.distributed.elastic.agent.server.api:Received 2 death signal, shutting down workers
# WARNING:torch.distributed.elastic.multiprocessing.api:Sending process 8229 closing signal SIGINT
# WARNING:torch.distributed.elastic.multiprocessing.api:Sending process 8230 closing signal SIGINT
# WARNING:torch.distributed.elastic.multiprocessing.api:Sending process 8231 closing signal SIGINT
# WARNING:torch.distributed.elastic.multiprocessing.api:Sending process 8232 closing signal SIGINT
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 599, in forward
#     return self.forward_once(x, profile)  # single-scale inference, train
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 627, in forward_once
#     x = m(x)  # run
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/common.py", line 113, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1151, in _call_impl
#     hook_result = hook(self, input, result)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/module_transform.py", line 74, in _forward_hook
#     return self.output_quantizer(output)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 216, in forward
#     return self._forward_fn(x, self.log_threshold, self.domain, self.method)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 202, in _quantize_with_warmup
#     log_threshold.data[0] = torch.log2(self._init_threshold(x))[0]
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 190, in _init_threshold
#     th = init_scheme[self.tensor_type](data)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 182, in _kl_j
#     d_tmp = calculate_kl_j(cdf[np.nonzero(cdf)], q[np.nonzero(cdf)])
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 148, in calculate_kl_j
#     return np.sum((x - y) * np.log2(x / y))
# KeyboardInterrupt
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 599, in forward
#     return self.forward_once(x, profile)  # single-scale inference, train
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 627, in forward_once
#     x = m(x)  # run
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/common.py", line 113, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1151, in _call_impl
#     hook_result = hook(self, input, result)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/module_transform.py", line 74, in _forward_hook
#     return self.output_quantizer(output)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 216, in forward
#     return self._forward_fn(x, self.log_threshold, self.domain, self.method)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 202, in _quantize_with_warmup
#     log_threshold.data[0] = torch.log2(self._init_threshold(x))[0]
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 190, in _init_threshold
#     th = init_scheme[self.tensor_type](data)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 182, in _kl_j
#     d_tmp = calculate_kl_j(cdf[np.nonzero(cdf)], q[np.nonzero(cdf)])
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 148, in calculate_kl_j
#     return np.sum((x - y) * np.log2(x / y))
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "train_qat.py", line 675, in <module>
#     train(hyp, opt, device, tb_writer)
#   File "train_qat.py", line 399, in train
#     pred = model(imgs)  # forward
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 1008, in forward
#     output = self._run_ddp_forward(*inputs, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 969, in _run_ddp_forward
#     return module_to_run(*inputs[0], **kwargs[0])
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/utils/torch_utils.py", line 605, in forward
#     x = instance.origin_forward(x)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 599, in forward
#     return self.forward_once(x, profile)  # single-scale inference, train
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 627, in forward_once
#     x = m(x)  # run
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/common.py", line 113, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1151, in _call_impl
#     hook_result = hook(self, input, result)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/module_transform.py", line 74, in _forward_hook
#     return self.output_quantizer(output)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 216, in forward
#     return self._forward_fn(x, self.log_threshold, self.domain, self.method)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 202, in _quantize_with_warmup
#     log_threshold.data[0] = torch.log2(self._init_threshold(x))[0]
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "train_qat.py", line 675, in <module>
#     train(hyp, opt, device, tb_writer)
#   File "train_qat.py", line 399, in train
#     pred = model(imgs)  # forward
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 1008, in forward
#     output = self._run_ddp_forward(*inputs, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/parallel/distributed.py", line 969, in _run_ddp_forward
#     return module_to_run(*inputs[0], **kwargs[0])
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/utils/torch_utils.py", line 605, in forward
#     x = instance.origin_forward(x)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 599, in forward
#     return self.forward_once(x, profile)  # single-scale inference, train
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/yolo.py", line 627, in forward_once
#     x = m(x)  # run
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/workspace/internal-models/pytorch/yolov7/yolov7/models/common.py", line 113, in forward
#     return self.act(self.bn(self.conv(x)))
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1151, in _call_impl
#     hook_result = hook(self, input, result)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/module_transform.py", line 74, in _forward_hook
#     return self.output_quantizer(output)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 216, in forward
#     return self._forward_fn(x, self.log_threshold, self.domain, self.method)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 202, in _quantize_with_warmup
#     log_threshold.data[0] = torch.log2(self._init_threshold(x))[0]
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 190, in _init_threshold
#     th = init_scheme[self.tensor_type](data)
#   File "/opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/quantization/modules/tqt.py", line 151, in _kl_j
#     mx = np.max(np.abs(x))
# KeyboardInterrupt
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ## Eval QAT model

# %% [markdown]
# ### run quantization

# %%
# %cd yolov7/
# !python test_nndct.py --data data/coco.yaml --img 640 --batch 1 --conf 0.001 --iou 0.65 --device 0 --weights ../quantized/qat.pt --name yolov7_640_val --quant_mode test --nndct_qat --nndct_convert_sigmoid_to_hsigmoid --nndct_convert_silu_to_hswish
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='data/coco.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolov7_640_val', nndct_qat=True, no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', v5_metric=False, verbose=False, weights=['../quantized/qat.pt'])
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
# Fusing layers...
# IDetect.fuse
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 417 layers, 36929178 parameters, 36929178 gradients, 105.2 GFLOPS
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 1040.1
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_NOTE]: =>Exporting quant config.(.vai_qat/quant_info.json)
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2786.5
#
# [VAIQ_WARN][QUANTIZER_TORCH_DEPRECATED_ARGUMENT]: "convert_to_deployable" is deprecated and will be removed in the future. Use "to_deployable" instead.
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization test process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2734.0
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.0.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.0.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.1.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.1.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.2.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.2.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.3.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.3.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.4.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.4.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.5.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.5.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.6.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.6.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.7.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.7.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.8.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.8.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.9.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.9.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.11.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.11.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.13.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.13.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.14.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.14.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.15.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.15.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.17.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.17.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.18.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.18.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.19.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.19.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.20.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.20.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.21.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.21.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.22.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.22.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.24.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.24.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.26.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.26.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.27.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.27.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.28.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.28.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.30.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.30.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.31.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.31.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.32.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.32.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.33.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.33.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.34.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.34.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.35.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.35.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.37.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.37.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.39.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.39.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.40.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.40.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.41.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.41.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.43.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.43.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.44.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.44.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.45.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.45.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.46.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.46.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.47.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.47.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.48.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.48.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.50.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.50.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv1.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv1.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv3.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv3.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv4.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv4.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv5.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv5.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv6.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv6.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv2.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv2.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv7.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv7.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.52.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.52.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.54.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.54.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.56.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.56.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.57.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.57.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.58.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.58.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.59.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.59.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.60.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.60.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.61.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.61.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.63.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.63.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.64.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.64.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.66.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.66.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.68.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.68.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.69.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.69.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.70.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.70.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.71.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.71.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.72.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.72.conv.bias.
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.73.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.73.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.75.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.75.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.77.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.77.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.78.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.78.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.79.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.79.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.81.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.81.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.82.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.82.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.83.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.83.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.84.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.84.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.85.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.85.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.86.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.86.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.88.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.88.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.90.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.90.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.91.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.91.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.92.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.92.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.94.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.94.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.95.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.95.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.96.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.96.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.97.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.97.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.98.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.98.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.99.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.99.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.101.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.101.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.102.rbr_reparam.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.102.rbr_reparam.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.103.rbr_reparam.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.103.rbr_reparam.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.104.rbr_reparam.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model

#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[101]/Conv2d[conv]/ret.553.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[101]/Hardswish[act]/ret.557.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/RepConv[model]/RepConv[102]/Conv2d[rbr_reparam]/ret.559.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/RepConv[model]/RepConv[102]/Hardswish[act]/ret.561.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/RepConv[model]/RepConv[103]/Conv2d[rbr_reparam]/ret.563.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/RepConv[model]/RepConv[103]/Hardswish[act]/ret.565.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/RepConv[model]/RepConv[104]/Conv2d[rbr_reparam]/ret.567.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/RepConv[model]/RepConv[104]/Hardswish[act]/ret.569.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/NNDctDetect[model]/NNDctDetect[105]/Conv2d[m]/ModuleList[0]/ret.571.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/NNDctDetect[model]/NNDctDetect[105]/Conv2d[m]/ModuleList[1]/ret.575.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/NNDctDetect[model]/NNDctDetect[105]/Conv2d[m]/ModuleList[2]/ret.579.
#
# [VAIQ_NOTE]: =>Exporting quant config.(nndct/test/quant_info.json)
# [VAIQ_NOTE]: =>Exporting quant config.(nndct/quant_info.json)
#
# [VAIQ_WARN][QUANTIZER_TORCH_SHIFT_CHECK]: bias Model::model.102.rbr_reparam.bias value is too small, so adjust the fix position from 26 to 20
#
# [VAIQ_WARN][QUANTIZER_TORCH_SHIFT_CHECK]: bias Model::model.103.rbr_reparam.bias value is too small, so adjust the fix position from 26 to 21
#
# [VAIQ_WARN][QUANTIZER_TORCH_SHIFT_CHECK]: bias Model::model.104.rbr_reparam.bias value is too small, so adjust the fix position from 26 to 21
#  Convert model to Traced-model...
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
#
# [VAIQ_NOTE]: OS and CPU information:
#                system --- Linux
#                  node --- xcdl190200
#               release --- 4.4.0-134-generic
#               version --- #160-Ubuntu SMP Wed Aug 15 14:58:00 UTC 2018
#               machine --- x86_64
#             processor --- x86_64
#
# [VAIQ_NOTE]: Tools version information:
#                   GCC --- GCC 9.4.0
#                python --- 3.7.12
#               pytorch --- 1.12.1
#         vai_q_pytorch --- 3.0.0+1bbeff9+torch1.12.1
#
# [VAIQ_NOTE]: GPU information:
#           device name --- Tesla P100-PCIE-16GB
#      device available --- True
#          device count --- 1
#        current device --- 0
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization test process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2358.6
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(nndct/Model.py)
#
# [VAIQ_NOTE]: =>Get module with quantization.
#  model is traced!
#
# val: Scanning 'coco/val2017.cache' images and labels... 4952 found, 48 missing,
#                Class      Images      Labels           P           R      mAP@.5
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input Model::input_0
#   key
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/prim_ops.py:116: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if not (list(self.node.out_tensors[0].shape[1:]) == list(input.size())[1:]):
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/torchquantizer.py:55: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if inf.sum() > 0 or nan.sum() > 0:
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/fix_ops.py:69: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   tensor.storage().size() != tensor.numel()):
#
# [VAIQ_NOTE]: Model_int.onnx is generated.(nndct/Model_int.onnx)
#
# [VAIQ_NOTE]: Model_int.pt is generated.(nndct/Model_int.pt)
#
# [VAIQ_NOTE]: =>Converting to xmodel ...
#
# [VAIQ_NOTE]: =>Dumping 'Model_0'' checking data...
#
# [VAIQ_NOTE]: =>Finsh dumping data.(nndct/deploy_check_data_int/Model_0)
#
# [VAIQ_NOTE]: =>Successfully convert 'Model_0' to xmodel.(nndct/Model_0_int.xmodel)
#                  all        5000       36335       0.739       0.614        0.67       0.463
# Speed: 104.1/1.1/105.2 ms inference/NMS/total per 640x640 image at batch-size 1
#
# Evaluating pycocotools mAP... saving runs/test/yolov7_640_val5/qat_predictions.json...
# loading annotations into memory...
# Done (t=0.45s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.16s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=57.16s).
# Accumulating evaluation results...
# DONE (t=10.51s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.479
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.526
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.516
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.366
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.603
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.655
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.498
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.698
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.803
# Results saved to runs/test/yolov7_640_val5
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ### dump QAT model

# %%
# %cd yolov7/
# !python test_nndct.py --data data/coco.yaml --img 640 --batch 1 --conf 0.001 --iou 0.65 --device 0 --weights ../quantized/qat.pt --name yolov7_640_val --quant_mode test --nndct_qat --nndct_convert_sigmoid_to_hsigmoid --nndct_convert_silu_to_hswish --dump_model
# %cd ../
# Out:
# /workspace/internal-models/pytorch/yolov7/yolov7
# Namespace(augment=False, batch_size=1, conf_thres=0.001, data='data/coco.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolov7_640_val', nndct_qat=True, no_trace=False, project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', v5_metric=False, verbose=False, weights=['../quantized/qat.pt'])
# YOLOR 🚀 ef59292b3 torch 1.12.1 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
#
# [VAIQ_NOTE]: Loading NNDCT kernels...
# Fusing layers...
# IDetect.fuse
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 417 layers, 36929178 parameters, 36929178 gradients, 105.2 GFLOPS
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization calibration process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 1151.2
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_NOTE]: =>Exporting quant config.(.vai_qat/quant_info.json)
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2818.1
#
# [VAIQ_WARN][QUANTIZER_TORCH_DEPRECATED_ARGUMENT]: "convert_to_deployable" is deprecated and will be removed in the future. Use "to_deployable" instead.
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization test process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2795.6
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(.vai_qat/Model.py)
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.0.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.0.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.1.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.1.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.2.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.2.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.3.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.3.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.4.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.4.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.5.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.5.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.6.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.6.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.7.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.7.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.8.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.8.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.9.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.9.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.11.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.11.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.13.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.13.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.14.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.14.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.15.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.15.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.17.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.17.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.18.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.18.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.19.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.19.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.20.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.20.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.21.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.21.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.22.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.22.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.24.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.24.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.26.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.26.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.27.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.27.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.28.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.28.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.30.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.30.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.31.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.31.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.32.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.32.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.33.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.33.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.34.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.34.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.35.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.35.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.37.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.37.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.39.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.39.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.40.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.40.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.41.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.41.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.43.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.43.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.44.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.44.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.45.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.45.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.46.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.46.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.47.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.47.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.48.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.48.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.50.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.50.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv1.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv1.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv3.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv3.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv4.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv4.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv5.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv5.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv6.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv6.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv2.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv2.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv7.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.51.cv7.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.52.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.52.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.54.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.54.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.56.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.56.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.57.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.57.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.58.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.58.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.59.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.59.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.60.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.60.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.61.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.61.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.63.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.63.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.64.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.64.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.66.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.66.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.68.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.68.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.69.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.69.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.70.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.70.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.71.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.71.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.72.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.72.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.73.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.73.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.75.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.75.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.77.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.77.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.78.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.78.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.79.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.79.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.81.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.81.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.82.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.82.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.83.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.83.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.84.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.84.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.85.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.85.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.86.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.86.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.88.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.88.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.90.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.90.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.91.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.91.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.92.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.92.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.94.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.94.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.95.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.95.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.96.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.96.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.97.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.97.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.98.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.98.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.99.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.99.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.101.conv.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.101.conv.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.102.rbr_reparam.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.102.rbr_reparam.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.103.rbr_reparam.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.103.rbr_reparam.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.104.rbr_reparam.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.104.rbr_reparam.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.105.m.0.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.105.m.0.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.105.m.1.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.105.m.1.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.105.m.2.weight.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::model.105.m.2.bias.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/QuantStub[quant]/10757.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[0]/Conv2d[conv]/ret.5.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[0]/Hardswish[act]/ret.9.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[1]/Conv2d[conv]/ret.11.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[1]/Hardswish[act]/ret.15.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[2]/Conv2d[conv]/ret.17.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[2]/Hardswish[act]/ret.21.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[3]/Conv2d[conv]/ret.23.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[3]/Hardswish[act]/ret.27.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[4]/Conv2d[conv]/ret.29.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Concat[model]/Concat[10]/Cat[cat]/ret.65.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[5]/Conv2d[conv]/ret.35.
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv[5]/Hardswish[act]/ret.39.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/Conv[model]/Conv

#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/NNDctDetect[model]/NNDctDetect[105]/Conv2d[m]/ModuleList[1]/ret.575.
#
# [VAIQ_WARN][QUANTIZER_TORCH_SCALE_VALUE]: Exported scale values are not trained: Model::Model/NNDctDetect[model]/NNDctDetect[105]/Conv2d[m]/ModuleList[2]/ret.579.
#
# [VAIQ_NOTE]: =>Exporting quant config.(nndct/test/quant_info.json)
# [VAIQ_NOTE]: =>Exporting quant config.(nndct/quant_info.json)
#
# [VAIQ_WARN][QUANTIZER_TORCH_SHIFT_CHECK]: bias Model::model.102.rbr_reparam.bias value is too small, so adjust the fix position from 26 to 20
#
# [VAIQ_WARN][QUANTIZER_TORCH_SHIFT_CHECK]: bias Model::model.103.rbr_reparam.bias value is too small, so adjust the fix position from 26 to 21
#
# [VAIQ_WARN][QUANTIZER_TORCH_SHIFT_CHECK]: bias Model::model.104.rbr_reparam.bias value is too small, so adjust the fix position from 26 to 21
#  Convert model to Traced-model...
# freezing model.105.ia.0.implicit
# freezing model.105.ia.1.implicit
# freezing model.105.ia.2.implicit
# freezing model.105.im.0.implicit
# freezing model.105.im.1.implicit
# freezing model.105.im.2.implicit
#
# [VAIQ_NOTE]: OS and CPU information:
#                system --- Linux
#                  node --- xcdl190200
#               release --- 4.4.0-134-generic
#               version --- #160-Ubuntu SMP Wed Aug 15 14:58:00 UTC 2018
#               machine --- x86_64
#             processor --- x86_64
#
# [VAIQ_NOTE]: Tools version information:
#                   GCC --- GCC 9.4.0
#                python --- 3.7.12
#               pytorch --- 1.12.1
#         vai_q_pytorch --- 3.0.0+1bbeff9+torch1.12.1
#
# [VAIQ_NOTE]: GPU information:
#           device name --- Tesla P100-PCIE-16GB
#      device available --- True
#          device count --- 1
#        current device --- 0
#
# [VAIQ_NOTE]: Quant config file is empty, use default quant configuration
#
# [VAIQ_NOTE]: Quantization test process start up...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Model...
#
# [VAIQ_WARN][QUANTIZER_TORCH_REPLACE_SILU]: SiLU has been replaced by Hardswish.
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model Model is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 300/300 [00:00<00:00, 2757.1
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(nndct/Model.py)
#
# [VAIQ_NOTE]: =>Get module with quantization.
#  model is traced!
#
# val: Scanning 'coco/val2017.cache' images and labels... 4952 found, 48 missing,
#                Class      Images      Labels           P           R      mAP@.5
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/torch/onnx/utils.py:1523: UserWarning: No names were found for specified dynamic axes of provided input.Automatically generated names will be applied to each dynamic axes of input Model::input_0
#   key
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/prim_ops.py:116: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if not (list(self.node.out_tensors[0].shape[1:]) == list(input.size())[1:]):
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/quantization/torchquantizer.py:55: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if inf.sum() > 0 or nan.sum() > 0:
# /opt/vitis_ai/conda/envs/vitis-ai-pytorch/lib/python3.7/site-packages/pytorch_nndct/nn/modules/fix_ops.py:69: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   tensor.storage().size() != tensor.numel()):
#
# [VAIQ_NOTE]: Model_int.onnx is generated.(nndct/Model_int.onnx)
#
# [VAIQ_NOTE]: Model_int.pt is generated.(nndct/Model_int.pt)
#
# [VAIQ_NOTE]: =>Converting to xmodel ...
#
# [VAIQ_NOTE]: =>Dumping 'Model_0'' checking data...
#
# [VAIQ_NOTE]: =>Finsh dumping data.(nndct/deploy_check_data_int/Model_0)
#
# [VAIQ_NOTE]: =>Successfully convert 'Model_0' to xmodel.(nndct/Model_0_int.xmodel)
# /workspace/internal-models/pytorch/yolov7

# %% [markdown]
# ## Performance
# | Model             | Input Size | Float mAP   | Quant mAP   | QAT mAP   | FLOPs  |
# |-------------------|------------|-------------|-------------|-------------|--------|
# | YOLOv7           | 640\*640   | 50.9%       | 40.8%       | 47.9%       | 104.8G  |
